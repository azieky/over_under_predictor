# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import random
import seaborn as sns
import math
import re
# %matplotlib inline

# %%
df = pd.read_csv('spreadspoke_scores.csv')

# %%
df.shape
# Out:
# (12934, 17)

# %%
df = df.dropna(subset=['over_under_line'])

# %%
df.isnull().sum()
# Out:
# schedule_date             0
# schedule_season           0
# schedule_week             0
# schedule_playoff          0
# team_home                 0
# score_home                0
# score_away                0
# team_away                 0
# team_favorite_id          0
# spread_favorite           0
# over_under_line           0
# stadium                   0
# stadium_neutral           0
# weather_temperature     595
# weather_wind_mph        595
# weather_humidity       4019
# weather_detail         7791
# dtype: int64

# %%
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# 1105      1/16/1972             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 12792     11/1/2020             2020             8             False
# 12793     11/1/2020             2020             8             False
# 12794     11/1/2020             2020             8             False
# 12795     11/1/2020             2020             8             False
# 12796     11/2/2020             2020             8             False
#
#                  team_home  score_home  score_away             team_away  \
# ...

# %%
df['total'] = df['score_home'] + df['score_away'] 
df = df.astype({'total': 'int'})

# %%
#df = df.astype({'over_under_line': 'float'})
df['over_under_line'].unique()
# Out:
# array(['43', '40', '39', '36', '34', '33', '38', '37', '30', '31', '31.5',
#        '36.5', '32', '41', '42.5', '35.5', '35', '40.5', '42', '44', '45',
#        '44.5', '39.5', ' ', '49', '47', '50', '48', '46', '37.5', '51',
#        '54', '38.5', '34.5', '49.5', '43.5', '45.5', '52', '41.5', '47.5',
#        '46.5', '52.5', '53', '48.5', '54.5', '55', '53.5', '51.5', '50.5',
#        '56', '33.5', '36.6', '32.5', '28', '29.5', '55.5', '58.5', '63',
#        '59.5', '58', '56.5', '57', '60', '30.5', '59', '57.5', '63.5',
#        '61.5'], dtype=object)

# %%
df = df[df.over_under_line != ' ']
df = df.astype({'over_under_line': 'float'})

# %%
df['covered'] = np.where(df['total'] > df['over_under_line'], 'Over', 'Under')

# %%
df.dtypes
# Out:
# schedule_date           object
# schedule_season          int64
# schedule_week           object
# schedule_playoff          bool
# team_home               object
# score_home             float64
# score_away             float64
# team_away               object
# team_favorite_id        object
# spread_favorite        float64
# over_under_line        float64
# stadium                 object
# stadium_neutral           bool
# weather_temperature    float64
# weather_wind_mph       float64
# weather_humidity        object
# weather_detail          object
# total                    int64
# covered                 object
# dtype: object

# %%
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# 1105      1/16/1972             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 12792     11/1/2020             2020             8             False
# 12793     11/1/2020             2020             8             False
# 12794     11/1/2020             2020             8             False
# 12795     11/1/2020             2020             8             False
# 12796     11/2/2020             2020             8             False
#
#                  team_home  score_home  score_away             team_away  \
# ...

# %%
df.dropna()
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 9774      9/27/2009             2009             3             False
# 9780      9/27/2009             2009             3             False
# 9781      9/27/2009             2009             3             False
# 9783      9/27/2009             2009             3             False
# 9797      10/4/2009             2009             4             False
# ...             ...              ...           ...               ...
# 11039    12/22/2013             2013            16             False
# 11045    12/22/2013             2013            16             False
# 11057    12/29/2013             2013            17             False
# 11059    12/29/2013             2013            17             False
# 11061    12/29/2013             2013            17             False
#
#                   team_home  score_home  score_away            team_away  \
# ...

# %%
#Default Count
print('Target Variable')
print(df.groupby(['covered']).covered.count())
# Out:
# Target Variable
# covered
# Over     4962
# Under    5284
# Name: covered, dtype: int64

# %%
df.shape
# Out:
# (10246, 19)
